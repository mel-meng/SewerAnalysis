# %% [markdown]
# # Optimization
#
#
# This [master thesis](https://www.researchgate.net/publication/333633442_Tiernan_Master's_Thesis_-_Developing_SWMMCALPY_an_automated_genetic_approach_to_calibrating_the_stormwater_management_model) has some very good information on optimization and calibration.
#
#
# Another good one is [Rules for responsible modeling](https://www.chiwater.com/Files/R184_CHI_Rules.pdf)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

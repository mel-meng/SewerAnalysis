# %%
import swmmio

#instantiate a swmmio model object
f = r"C:\Users\Mel.Meng\Documents\GitHub\SewerAnalysis\examples\scenarios\data\alt_test1.inp"
mymodel = swmmio.Model(f)

#Pandas dataframe with most useful data related to model nodes, conduits, and subcatchments
nodes = mymodel.nodes()
conduits = mymodel.conduits()
subs = mymodel.subcatchments()

#enjoy all the Pandas functions
nodes.head()
# Out:
#              InvertElev  MaxDepth  InitDepth  SurchargeDepth  PondedArea  \
# Name
# dummy_node1      -10.99  30.00000        0.0             0.0         0.0
# dummy_node2       -9.24  20.00000        0.0             0.0         0.0
# dummy_node3       -7.76  20.00000        0.0             0.0         0.0
# dummy_node4       -6.98  12.59314        0.0             0.0    177885.0
# dummy_node5       -6.96  13.05439        0.0             0.0     73511.0
#
#             OutfallType StageOrTimeseries  TideGate  \
# Name
# dummy_node1         NaN               NaN       NaN
# dummy_node2         NaN               NaN       NaN
# dummy_node3         NaN               NaN       NaN
# dummy_node4         NaN               NaN       NaN
# dummy_node5         NaN               NaN       NaN
#
#                                        coords
# Name
# dummy_node1  [(2054.575, 6051.3640000000005)]
# dummy_node2             [(-2937.4, 7704.655)]
# dummy_node3           [(-4205.457, 9695.024)]
# dummy_node4          [(-6163.724, 12857.143)]
# dummy_node5          [(-9871.589, 13723.917)]

# %%
from swmmio.graphics import swmm_graphics as sg
sg.draw_model(mymodel)
# Out:
# <PIL.Image.Image image mode=RGB size=4096x2239 at 0x2B5DFCAFDA0>

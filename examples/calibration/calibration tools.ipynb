# %% [markdown]
# # Calibration Tools
#
# I will use the framework outlined in the [Rules for responsible modeling](https://www.chiwater.com/Files/R184_CHI_Rules.pdf) to show how to calibrate the RTK parameters to fit the flow data for one flow meter.
#
# I am quite excited about this article, I've been dreaming to be able to do most of my calibration in python a long time ago, but was never able to do it for the reasons below,
# - I am not familiar with pySWMM and plotly at that time
# - Some of the features were only available recent years
# - I couldn't find the time to work them (the tools I used then would take 10 times the effort then)
#
# I hope this article will demonstrate the value of python, or an automated way of calibration. I firmly believe we need better tooling when it comes to calibration, and such tool can unlock the real power of a model for new type of applications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The code is too complicated to test and debug in a notebook, and I place them in the source folder so that I can properly test it. I need to first import the calibration_tools library which I programed all the helper functions to perform the above steps.
#
# **You need to change the path below to the path where you downloaded the source folder.**

# %%
import sys
lib_path = r'C:\Users\Mel.Meng\Documents\GitHub\SewerAnalysis\source'
if lib_path not in sys.path:
    sys.path.append(lib_path)
sys.path

import calibration_tools

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I think using a rolling window might help me to get a better description of the shape of the hydrograph.
